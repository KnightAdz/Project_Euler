# %% [markdown]
# The four adjacent digits in the 1000-digit number that have the greatest product are 9 × 9 × 8 × 9 = 5832.
#
# <code>73167176531330624919225119674426574742355349194934
# 96983520312774506326239578318016984801869478851843
# 85861560789112949495459501737958331952853208805511
# 12540698747158523863050715693290963295227443043557
# 66896648950445244523161731856403098711121722383113
# 62229893423380308135336276614282806444486645238749
# 30358907296290491560440772390713810515859307960866
# 70172427121883998797908792274921901699720888093776
# 65727333001053367881220235421809751254540594752243
# 52584907711670556013604839586446706324415722155397
# 53697817977846174064955149290862569321978468622482
# 83972241375657056057490261407972968652414535100474
# 82166370484403199890008895243450658541227588666881
# 16427171479924442928230863465674813919123162824586
# 17866458359124566529476545682848912883142607690042
# 24219022671055626321111109370544217506941658960408
# 07198403850962455444362981230987879927244284909188
# 84580156166097919133875499200524063689912560717606
# 05886116467109405077541002256983155200055935729725
# 71636269561882670428252483600823257530420752963450</code>
#
# Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?

# %%
import numpy as np

# %%
big_num = "..."

# %%
len(big_num)
# Out:
# 1000

# %% [markdown]
# Simplifcation: Numbers including a 0 won't have the largest sum, so let's split into smaller strings and discard any less than 13 digits in length

# %%
no_zeroes = big_num.split("0")

# %%
smaller_nums = list(filter(lambda x: len(x)>=13,no_zeroes))

# %%
smaller_nums
# Out:
# ['7316717653133',
#  '6249192251196744265747423553491949349698352',
#  '6326239578318',
#  '18694788518438586156',
#  '7891129494954595',
#  '17379583319528532',
#  '698747158523863',
#  '435576689664895',
#  '4452445231617318564',
#  '987111217223831136222989342338',
#  '81353362766142828',
#  '64444866452387493',
#  '1724271218839987979',
#  '9377665727333',
#  '594752243525849',
#  '632441572215539753697817977846174',
#  '86256932197846862248283972241375657',
#  '79729686524145351',
#  '6585412275886668811642717147992444292823',
#  '863465674813919123162824586178664583591245665294765456828489128831426',
#  '96245544436298123',
#  '9878799272442849',
#  '979191338754992',
#  '559357297257163626956188267']

# %%
thirt_nums = []
idx=13
for x in smaller_nums:
    while len(x)>=13:
        thirt_nums.append(x[0:idx])
        x = x[1:]

thirt_nums
# Out:
# ['7316717653133',
#  '6249192251196',
#  '2491922511967',
#  '4919225119674',
#  '9192251196744',
#  '1922511967442',
#  '9225119674426',
#  '2251196744265',
#  '2511967442657',
#  '5119674426574',
#  '1196744265747',
#  '1967442657474',
#  '9674426574742',
#  '6744265747423',
#  '7442657474235',
#  '4426574742355',
#  '4265747423553',
#  '2657474235534',
#  '6574742355349',
#  '5747423553491',
#  '7474235534919',
#  '4742355349194',
#  '7423553491949',
#  '4235534919493',
#  '2355349194934',
#  '3553491949349',
#  '5534919493496',
#  '5349194934969',
#  '3491949349698',
#  '4919493496983',
#  '9194934969835',
#  '1949349698352',
#  '6326239578318',
#  '1869478851843',
#  '8694788518438',
#  '6947885184385',
#  '9478851843858',
#  '4788518438586',
#  '7885184385861',
#  '8851843858615',
#  '8518438586156',
#  '7891129494954',
#  '8911294949545',
#  '9112949495459',
#  '1129494954595',
#  '1737958331952',
#  '7379583319528',
#  '3795833195285',
#  '7958331952853',
#  '9583319528532',
# ...

# %%
max_prod = 0
for s in thirt_nums:
    # calculate product
    this_prod=np.product([int(d) for d in s], dtype=np.int64)
    
    print(this_prod)
    # if larger than current max sum, save the value
    if this_prod > max_prod:
        max_prod = this_prod
        
print(max_prod)
# Out:
# 5000940
# 4199040
# 4898880
# 9797760
# 9797760
# 2177280
# 13063680
# 7257600
# 25401600
# 50803200
# 71124480
# 284497920
# 568995840
# 189665280
# 158054400
# 112896000
# 84672000
# 84672000
# 381024000
# 63504000
# 114307200
# 65318400
# 146966400
# 62985600
# 62985600
# 283435200
# 566870400
# 1020366720
# 1632586752
# 1632586752
# 2040733440
# 453496320
# 78382080
# 371589120
# 2972712960
# 1857945600
# 2477260800
# 1651507200
# 412876800
# 294912000
# 221184000
# 235146240
# 167961600
# 188956800
# 104976000
# 42865200
# 342921600
# 244944000
# 244944000
# 69984000
# 812851200
# 812851200
# 270950400
# 6270566400
# 14108774400
# 23514624000
# 3225600
# 2419200
# 604800
# 967680
# 2419200
# 3628800
# 3628800
# 677376
# 225792
# 28224
# 4032
# 12096
# 72576
# 145152
# 145152
# 290304
# 373248
# 1492992
# 6718464
# 6718464
# 3359232
# 2239488
# 6718464
# 20155392
# 53747712
# 13063680
# 3265920
# 26127360
# 17418240
# 27869184
# 424673280
# 495452160
# 495452160
# 1114767360
# ...
